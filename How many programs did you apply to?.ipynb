# %%
# %matplotlib inline
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font_scale=2)

# %%
responses = {
    "Sebastian": 11,
    "Roma": 10,
    "Nicholas": 15,
    "Nelson": 12,
    "Michi": 10,
    "Lucy": 8,
    "Kevin": 4,
    "Kalpesh": 13,  # 9 PhD, 4 MS
    "Eric": 9,
    "Akari": 11,
    "Aishwarya": 6
}

aggregated_responses = {
    "Less than 5": 1,
    "6 to 9": 3,
    "10 to 13": 6,
    "More than 13": 1
}

# %%
plt.figure(figsize=(10, 10))
labels, counts = zip(*aggregated_responses.items())
plt.bar(labels, counts, align='center')
plt.title("How many NLP PhD programs did you apply to?")
plt.xlabel("Number of applications")
plt.ylabel("Number of respondents")

plt.savefig("number_of_applications.png", bbox_inches="tight", pad_inches=0)
